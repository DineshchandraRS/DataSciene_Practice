# %%
#video-21

# %%
import pandas as pd

# %%
drinks = pd.read_csv("drinks.csv")

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.memory_usage(deep = True)
# Out:
# Index                             128
# country                         12588
# beer_servings                    1544
# spirit_servings                  1544
# wine_servings                    1544
# total_litres_of_pure_alcohol     1544
# continent                       12332
# dtype: int64

# %%
drinks['continent'] = drinks.continent.astype('category')

# %%
drinks.dtypes
# Out:
# country                           object
# beer_servings                      int64
# spirit_servings                    int64
# wine_servings                      int64
# total_litres_of_pure_alcohol     float64
# continent                       category
# dtype: object

# %%
sorted(drinks.continent.unique())
# Out:
# ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

# %%
drinks.continent.head()
# Out:
# 0      Asia
# 1    Europe
# 2    Africa
# 3    Europe
# 4    Africa
# Name: continent, dtype: category
# Categories (6, object): ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

# %%
drinks.continent.cat.codes.head()
# Out:
# 0    1
# 1    2
# 2    0
# 3    2
# 4    0
# dtype: int8

# %%
drinks.memory_usage(deep = True)
# Out:
# Index                             128
# country                         12588
# beer_servings                    1544
# spirit_servings                  1544
# wine_servings                    1544
# total_litres_of_pure_alcohol     1544
# continent                         756
# dtype: int64

# %%
df = pd.DataFrame({"ID": [100, 101, 102, 104], "Quality": ["Good", "Very Good", "Excellent", 'Good']})

# %%
df.head()
# Out:
#     ID    Quality
# 0  100       Good
# 1  101  Very Good
# 2  102  Excellent
# 3  104       Good

# %%
df.Quality.sort_values()
# Out:
# 2    Excellent
# 0         Good
# 3         Good
# 1    Very Good
# Name: Quality, dtype: object

# %%
df['Quality'] = df.Quality.Categorical('category', categories = ["Good", "Very Good", "Excellent"], ordered = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9916\3023887220.py in <module>
# ----> 1 df['Quality'] = df.Quality.Categorical('category', categories = ["Good", "Very Good", "Excellent"], ordered = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'Categorical'

# %%
df.Quality.sort_values()
# Out:
# 2    Excellent
# 0         Good
# 3         Good
# 1    Very Good
# Name: Quality, dtype: category
# Categories (3, object): ['Excellent', 'Good', 'Very Good']

# %%
# Video-23

# %%
import pandas as pd

# %%
ufo = pd.read_csv("ufo.csv")

# %%
ufo.sample(n=3)
# Out:
#                 City Colors Reported Shape Reported State              Time
# 12606         Aurora             NaN       TRIANGLE    CO  11/20/1998 20:00
# 15945  Cottage Grove             NaN      FORMATION    OR   2/20/2000 22:30
# 6233           Davis             NaN       TRIANGLE    CA  11/24/1989 13:30

# %%
ufo.sample(n=3, random_state = 42)
# Out:
#                City Colors Reported Shape Reported State              Time
# 217    Norridgewock             NaN           DISK    ME   9/15/1952 14:00
# 12282         Ipava             NaN       TRIANGLE    IL   10/1/1998 21:15
# 17933     Ellinwood             NaN       FIREBALL    KS  11/13/2000 22:00

# %%
ufo.sample(frac = 0.5, random_state = 99)
# Out:
#                  City Colors Reported Shape Reported State              Time
# 6250        Sunnyvale             NaN          OTHER    CA   12/16/1989 0:00
# 8656   Corpus Christi             NaN            NaN    TX    9/13/1995 0:10
# 2729           Mentor             NaN           DISK    OH    8/8/1974 10:00
# 7348           Wilson             NaN          LIGHT    WI     6/1/1994 1:00
# 12637          Lowell             NaN         CIRCLE    MA  11/26/1998 10:00
# ...               ...             ...            ...   ...               ...
# 860    Valley Station             NaN          OTHER    KY   4/15/1964 19:00
# 1651         Hueytown             NaN           OVAL    AL    6/30/1968 9:00
# 8189    Mercer Island             NaN       TRIANGLE    WA    6/1/1995 21:00
# 7252         Honolulu             NaN          LIGHT    HI     1/1/1994 0:00
# 5167      St. Charles             RED        VARIOUS    IL  11/26/1984 22:00
#
# [9120 rows x 5 columns]

# %%
# Video-24

# %%
import pandas as pd

# %%
train = pd.read_csv("http://bit.ly/kaggletrain")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train['sex_male'] = train.Sex.map({"female":0, "male":1})

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sex_male
# 0      0         A/5 21171   7.2500   NaN        S         1
# 1      0          PC 17599  71.2833   C85        C         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0
# 3      0            113803  53.1000  C123        S         0
# ...

# %%
pd.get_dummies(train.Sex, prefix = "sex")
# Out:
#      sex_female  sex_male
# 0             0         1
# 1             1         0
# 2             1         0
# 3             1         0
# 4             0         1
# ..          ...       ...
# 886           0         1
# 887           1         0
# 888           1         0
# 889           0         1
# 890           0         1
#
# [891 rows x 2 columns]

# %%
sex_dummies = pd.get_dummies(train.Sex, prefix = "sex").iloc[:, 1:]

# %%
train = pd.concat([train, sex_dummies], axis = 1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sex_male  sex_male
# 0      0         A/5 21171   7.2500   NaN        S         1         1
# 1      0          PC 17599  71.2833   C85        C         0         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0         0
# ...

# %%
train.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
pd.get_dummies(train.Embarked, prefix = "Embarked")
# Out:
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [891 rows x 3 columns]

# %%
embarked_dummies = pd.get_dummies(train.Embarked, prefix = "Embarked").iloc[:, 1:]

# %%
train = pd.concat([train, embarked_dummies], axis = 1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sex_male  sex_male  \
# 0      0         A/5 21171   7.2500   NaN        S         1         1
# 1      0          PC 17599  71.2833   C85        C         0         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0         0
# ...

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sex_male  sex_male  \
# 0      0         A/5 21171   7.2500   NaN        S         1         1
# 1      0          PC 17599  71.2833   C85        C         0         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0         0
# ...

# %%
train = pd.read_csv("http://bit.ly/kaggletrain")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.get_dummies(train, columns = ['Sex', 'Embarked'], drop_first = True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
#Video-25

# %%
import pandas as pd

# %%
ufo = pd.read_csv("ufo.csv")

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
ufo.Time.str.slice(-5, -3).astype(int).head()
# Out:
# 0    22
# 1    20
# 2    14
# 3    13
# 4    19
# Name: Time, dtype: int32

# %%
ufo['Time'] = pd.to_datetime(ufo.Time)

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
ufo.Time.dt.weekday
# Out:
# 0        6
# 1        0
# 2        6
# 3        0
# 4        1
#         ..
# 18236    6
# 18237    6
# 18238    6
# 18239    6
# 18240    6
# Name: Time, Length: 18241, dtype: int64

# %%
ts = pd.to_datetime('1/20/1991')

# %%
ufo.loc[ufo.Time >= ts, :].head()
# Out:
#                      City Colors Reported Shape Reported State  \
# 6500            Scarsdale             NaN          OTHER    NY
# 6501            Quartzite             RED          LIGHT    AZ
# 6502  Washington Township             NaN          OTHER    NJ
# 6503                Selma             NaN      RECTANGLE    CA
# 6504            Calistoga             NaN         SPHERE    CA
#
#                     Time
# 6500 1991-01-20 03:00:00
# 6501 1991-02-01 20:00:00
# 6502 1991-02-11 14:00:00
# 6503 1991-02-14 22:00:00
# 6504 1991-02-15 15:00:00

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
ufo.Time.max()
# Out:
# Timestamp('2000-12-31 23:59:00')

# %%
ufo.Time.min()
# Out:
# Timestamp('1930-06-01 22:00:00')

# %%
(ufo.Time.max() - ufo.Time.min()).days
# Out:
# 25781

# %%
# %matplotlib inline

# %%
ufo['Year'] = ufo.Time.dt.year

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %%
ufo.Year.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
#Video-26

# %%
import  pandas as pd

# %%
user_cols = ["user_id", "Age", "Gender", "Occupation", "Zip_Code"]
users = pd.read_table("http://bit.ly/movieusers", sep="|", header=None, names=user_cols)

# %%
users.head()
# Out:
#    user_id  Age Gender  Occupation Zip_Code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users.Zip_Code.duplicated().sum()
# Out:
# 148

# %%
users.duplicated().sum()
# Out:
# 0

# %%
users.loc[users.duplicated(keep = 'first'), :]
# Out:
# Empty DataFrame
# Columns: [user_id, Age, Gender, Occupation, Zip_Code]
# Index: []

# %%
users.loc[users.duplicated(keep = False), :]
# Out:
# Empty DataFrame
# Columns: [user_id, Age, Gender, Occupation, Zip_Code]
# Index: []

# %%
users.drop_duplicates(subset = ['Age', 'Zip_Code'], keep = 'first').shape
# Out:
# (927, 5)

# %%
users.Zip_Code.drop_duplicates(keep = 'first').shape
# Out:
# (795,)

# %%
users.Zip_Code.shape
# Out:
# (943,)

# %%
#Video-27

# %%
import pandas as pd

# %%
movies = pd.read_csv("imdb.csv")

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.content_rating.isnull().sum()
# Out:
# 3

# %%
movies[movies.content_rating.isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movies.content_rating.value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
import numpy as np

# %%
movies[movies.content_rating == "NOT RATED"].content_rating = np.nan
# Out:
# C:\Users\dinu8\AppData\Local\Temp\ipykernel_9916\95245742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies[movies.content_rating == "NOT RATED"].content_rating = np.nan

# %%
movies.content_rating.isnull().sum()
# Out:
# 3

# %%
movies.loc[movies.content_rating == "NOT RATED", "content_rating"] = np.nan

# %%
movies.content_rating.isnull().sum()
# Out:
# 68

# %%
top_movies = movies.loc[movies.star_rating >= 9, :]

# %%
top_movies
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
# to change the movies duration in the first row

# %%
top_movies.loc[0, 'duration'] = 150

# %%
top_movies
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       150
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
#Video-28

# %%
import pandas as pd

# %%
drinks = pd.read_csv("drinks.csv")

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
pd.reset_option('display.max_rows')

# %%
train = pd.read_csv("http://bit.ly/kaggletrain")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 0      0         A/5 21171   7.25   NaN        S
# 1      0          PC 17599  71.28   C85        C
# 2      0  STON/O2. 3101282   7.92   NaN        S
# 3      0            113803  53.10  C123        S
# 4      0            373450   8.05   NaN        S

# %%
pd.get_option('display.max_colwidth')
# Out:
# 50

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
pd.get_option('display.precision')
# Out:
# 6

# %%
pd.set_option('display.precision', 2)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks['x'] = drinks.wine_servings * 1000

# %%
drinks['y'] = drinks.total_litres_of_pure_alcohol	 * 1000

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent       x        y
# 0                           0.0      Asia       0      0.0
# 1                           4.9    Europe   54000  4,900.0
# 2                           0.7    Africa   14000    700.0
# 3                          12.4    Europe  312000 12,400.0
# 4                           5.9    Africa   45000  5,900.0

# %%
pd.set_option('display.float_format', '{:,}'.format)

# %%
pd.describe_option()
# Out:
# compute.use_bottleneck : bool
#     Use the bottleneck library to accelerate if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# compute.use_numba : bool
#     Use the numba engine option for select operations if it is installed,
#     the default is False
#     Valid values: False,True
#     [default: False] [currently: False]
# compute.use_numexpr : bool
#     Use the numexpr library to accelerate computation if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller then the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
# ...

# %%
pd.describe_option('rows')
# Out:
# display.max_info_rows : int or None
#     df.info() will usually show null-counts for each column.
#     For large frames this can be quite slow. max_info_rows and max_info_cols
#     limit this null check only to frames with smaller dimensions than
#     specified.
#     [default: 1690785] [currently: 1690785]
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 60]
# display.min_rows : int
# ...

# %%
#Video-29

# %%
import pandas as pd

# %%
df = pd.DataFrame({'id': [100,101,102], 'Color': ['red','blue', 'red']}, columns = ['id','Color'], index = ['a', 'b', 'c'])

# %%
 pd.DataFrame([[100, 'red'], [101, 'blue'], [102, 'red']], columns = ['id', 'color'])
# Out:
#     id color
# 0  100   red
# 1  101  blue
# 2  102   red

# %%
import numpy as np

# %%
#Create an array with 4 rows and 2 columns between 0 & 1
arr = np.random.rand(4, 2)

# %%
arr
# Out:
# array([[0.83412721, 0.44658811],
#        [0.45010136, 0.06206754],
#        [0.80109862, 0.08328269],
#        [0.80992098, 0.82798848]])

# %%
pd.DataFrame(arr, columns = ['one', 'two'])
# Out:
#                   one                  two
# 0  0.6753031459128999  0.16910124287489758
# 1 0.37615424271536235   0.9975232927158207
# 2  0.9535064578687943  0.37121378096227187
# 3 0.27015721453234154 0.061310539446476686

# %%
pd.DataFrame({'student': np.arange(100, 110, 1), 'test_scores':np.random.randint(60, 101, 10)})
# Out:
#    student  test_scores
# 0      100           94
# 1      101           68
# 2      102           62
# 3      103           95
# 4      104           89
# 5      105           73
# 6      106           98
# 7      107           66
# 8      108           94
# 9      109           98

# %%
pd.DataFrame({'student': np.arange(100, 110, 1), 'test_scores':np.random.randint(60, 101, 10)}).set_index('student')
# Out:
#          test_scores
# student
# 100               77
# 101               65
# 102               64
# 103               60
# 104               62
# 105               63
# 106               69
# 107               80
# 108               77
# 109               93

# %%
s = pd.Series(['round', 'square'], index = ['c', 'b'], name = 'shape')

# %%
df
# Out:
#     id Color
# a  100   red
# b  101  blue
# c  102   red

# %%
pd.concat([df, s], axis = 1)
# Out:
#     id Color   shape
# a  100   red     NaN
# b  101  blue  square
# c  102   red   round

# %%
#Video-30

# %%
import pandas as pd

# %%
train = pd.read_csv("http://bit.ly/kaggletrain")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female 38.0      1
# 2                               Heikkinen, Miss. Laina  female 26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.0      1
# 4                             Allen, Mr. William Henry    male 35.0      0
#
#    Parch            Ticket    Fare Cabin Embarked
# 0      0         A/5 21171    7.25   NaN        S
# 1      0          PC 17599 71.2833   C85        C
# 2      0  STON/O2. 3101282   7.925   NaN        S
# 3      0            113803    53.1  C123        S
# 4      0            373450    8.05   NaN        S

# %%
train['sex_num'] = train.Sex.map({'female':0, 'male':1})

# %%
train.loc[0:4, ['Sex', 'sex_num']]
# Out:
#       Sex  sex_num
# 0    male        1
# 1  female        0
# 2  female        0
# 3  female        0
# 4    male        1

# %%
train['name_length'] = train.Name.apply(len)

# %%
train.loc[0:4, ['Name', 'name_length']]
# Out:
#                                                   Name  name_length
# 0                              Braund, Mr. Owen Harris           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)           51
# 2                               Heikkinen, Miss. Laina           22
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           44
# 4                             Allen, Mr. William Henry           24

# %%
import numpy as np

# %%
train['fare_ceil'] = train.Fare.apply(np.ceil)

# %%
train.loc[0:4, ['Fare', 'fare_ceil']]
# Out:
#      Fare  fare_ceil
# 0    7.25        8.0
# 1 71.2833       72.0
# 2   7.925        8.0
# 3    53.1       54.0
# 4    8.05        9.0

# %%
train.Name.str.split(',').head()
# Out:
# 0                                [Braund,  Mr. Owen Harris]
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs Thayer)]
# 2                                 [Heikkinen,  Miss. Laina]
# 3           [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                               [Allen,  Mr. William Henry]
# Name: Name, dtype: object

# %%
def get_element(my_list, position):
    return my_list[position]

# %%
train.Name.str.split(',').apply(get_element, position = 0).head(10)
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# 5        Moran
# 6     McCarthy
# 7      Palsson
# 8      Johnson
# 9       Nasser
# Name: Name, dtype: object

# %%
train.Name.str.split(',').apply(lambda x:x[0]).head(10)
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# 5        Moran
# 6     McCarthy
# 7      Palsson
# 8      Johnson
# 9       Nasser
# Name: Name, dtype: object

# %%
import pandas as pd

# %%
drinks = pd.read_csv('drinks.csv')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0              0                0              0
# 1             89              132             54
# 2             25                0             14
# 3            245              138            312
# 4            217               57             45

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].apply(max, axis = 0)
# Out:
# beer_servings      376
# spirit_servings    438
# wine_servings      370
# dtype: int64

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].apply(max, axis = 1)
# Out:
# 0        0
# 1      132
# 2       25
# 3      312
# 4      217
#       ...
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Length: 193, dtype: int64

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].apply(np.argmax, axis = 0)
# Out:
# beer_servings      117
# spirit_servings     68
# wine_servings       61
# dtype: int64

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].apply(np.argmax, axis = 1)
# Out:
# 0      0
# 1      1
# 2      0
# 3      2
# 4      0
#       ..
# 188    0
# 189    0
# 190    0
# 191    0
# 192    0
# Length: 193, dtype: int64

# %%
drinks.loc[:, 'beer_servings':'wine_servings'].applymap(float)
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188          333.0            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
# [193 rows x 3 columns]

# %%
drinks.loc[:, 'beer_servings':'wine_servings'] = drinks.loc[:, 'beer_servings':'wine_servings'].applymap(float)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa
