# %%
import pandas as pd

# %%
data = pd.read_csv('rainfall-dataset - Sheet1.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN                      State       YEAR        JAN        FEB
# 1         NaN  Andaman & Nicobar Islands       1901       49.2       87.1
# 2         NaN  Andaman & Nicobar Islands       1902          0      159.8
# 3         NaN  Andaman & Nicobar Islands       1903       12.7        144
# 4         NaN  Andaman & Nicobar Islands       1904        9.4       14.7
# 5         NaN  Andaman & Nicobar Islands       1905        1.3          0
# 6         NaN  Andaman & Nicobar Islands       1906       36.6          0
# 7         NaN  Andaman & Nicobar Islands       1907      110.7          0
# 8         NaN  Andaman & Nicobar Islands       1908       20.9       85.1
# 9         NaN  Andaman & Nicobar Islands       1910       26.6       22.7
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        MAR        APR        MAY        JUN        JUL         AUG
# ...

# %%
data.tail(10)
# Out:
#       Unnamed: 0   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 4178         NaN  Lakshadweep       2007        2.5        4.2        0.2
# 4179         NaN  Lakshadweep       2008        5.5       19.8      120.7
# 4180         NaN  Lakshadweep       2009        4.7        1.5        0.1
# 4181         NaN  Lakshadweep       2010       18.8          0        1.2
# 4182         NaN  Lakshadweep       2011        5.1        2.8        3.1
# 4183         NaN  Lakshadweep       2012       19.2        0.1        1.6
# 4184         NaN  Lakshadweep       2013       26.2       34.4       37.5
# 4185         NaN  Lakshadweep       2014       53.2       16.1        4.4
# 4186         NaN  Lakshadweep       2015        2.2        0.5        3.7
# 4187         NaN  Lakshadweep       2016       59.6       12.1        3.2
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 4178       22.2      166.2      573.4      427.4       294.7       457.5
# ...

# %%
1) What is total rainfall across all years (1901-2017) for the state "Punjab"assigned?

2) What is average annual rainfall across years (1901-2017) for the state "Andaman & Nicobar Islands"?

3) What is the average monthly rainfall for the state "Jharkhand" for the year "1974"

4) What is the annual rainfall for the state "Gujarat Region" for the year "1985"
# Out:
#   File "C:\Users\dinu8\AppData\Local\Temp\ipykernel_14548\2952440777.py", line 3
#     2) What is average annual rainfall across years (1901-2017) for the state "Andaman & Nicobar Islands"?
#      ^
# SyntaxError: unmatched ')'

# %%
data.dtypes
# Out:
# Unnamed: 0     float64
# Unnamed: 1      object
# Unnamed: 2      object
# Unnamed: 3      object
# Unnamed: 4      object
# Unnamed: 5      object
# Unnamed: 6      object
# Unnamed: 7      object
# Unnamed: 8      object
# Unnamed: 9      object
# Unnamed: 10     object
# Unnamed: 11     object
# Unnamed: 12     object
# Unnamed: 13     object
# Unnamed: 14     object
# dtype: object

# %%
data = data.rename(columns = data.iloc[0], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14548\156661728.py in <module>
# ----> 1 data = data.rename(columns = data.iloc[0], inplace = True)
#
# AttributeError: 'NoneType' object has no attribute 'rename'

# %%
data

# %%
data = data.drop([0], axis = 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14548\3642710428.py in <module>
# ----> 1 data = data.drop([0], axis = 0)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
data

# %%
data.iloc[:, 3:15].astype('float')

# %%
# Out:
#       NaN                      State  YEAR   JAN    FEB   MAR    APR    MAY  \
# 1     NaN  Andaman & Nicobar Islands  1901  49.2   87.1  29.2    2.3  528.8
# 2     NaN  Andaman & Nicobar Islands  1902     0  159.8  12.2      0  446.1
# 3     NaN  Andaman & Nicobar Islands  1903  12.7    144     0      1  235.1
# 4     NaN  Andaman & Nicobar Islands  1904   9.4   14.7     0  202.4  304.5
# 5     NaN  Andaman & Nicobar Islands  1905   1.3      0   3.3   26.9  279.5
# ...   ...                        ...   ...   ...    ...   ...    ...    ...
# 4183  NaN                Lakshadweep  2012  19.2    0.1   1.6   76.8   21.2
# 4184  NaN                Lakshadweep  2013  26.2   34.4  37.5    5.3   88.3
# 4185  NaN                Lakshadweep  2014  53.2   16.1   4.4   14.9   57.4
# 4186  NaN                Lakshadweep  2015   2.2    0.5   3.7   87.1  133.1
# 4187  NaN                Lakshadweep  2016  59.6   12.1   3.2    2.6   77.4
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC
# ...

# %%
data.dtypes
# Out:
# NaN      float64
# State     object
# YEAR      object
# JAN       object
# FEB       object
# MAR       object
# APR       object
# MAY       object
# JUN       object
# JUL       object
# AUG       object
# SEP       object
# OCT       object
# NOV       object
# DEC       object
# dtype: object

# %%
s = data.loc[(data.State == 'Punjab') & (data.YEAR >= 1901), data.columns[3:15]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14548\2610839045.py in <module>
# ----> 1 s = data.loc[(data.State == 'Punjab') & (data.YEAR >= 1901), data.columns[3:15]]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'State'

# %%
s.sum().sum()
# Out:
# 69198.70000000001

# %%
df_3 = data.loc[(data.State == 'Jharkhand') & (data.YEAR == 1974), data.columns[3:15]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14548\2690322404.py in <module>
# ----> 1 df_3 = data.loc[(data.State == 'Jharkhand') & (data.YEAR == 1974), data.columns[3:15]]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'State'

# %%
df_3.mean().mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14548\2111496860.py in <module>
# ----> 1 df_3.mean().mean()
#
# NameError: name 'df_3' is not defined

# %%
df_4 = data.loc[(data.State == "Gujarat Region") & (data.YEAR == 1985), data.columns[3:15]]

# %%
df_4.sum().sum()
# Out:
# 589.7

# %%
df_2 = data.loc[(data.State == "Andaman & Nicobar Islands"), data.columns[3:15]]

# %%
df_2.mean().sum()
# Out:
# 2901.7044569631253

# %%
df_2
# Out:
#        JAN    FEB   MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0     49.2   87.1  29.2    2.3  528.8  517.5  365.1  481.1  332.6  388.5
# 1      0.0  159.8  12.2    0.0  446.1  537.1  228.9  753.7  666.2  197.2
# 2     12.7  144.0   0.0    1.0  235.1  479.9  728.4  326.7  339.0  181.2
# 3      9.4   14.7   0.0  202.4  304.5  495.1  502.0  160.1  820.4  222.2
# 4      1.3    0.0   3.3   26.9  279.5  628.7  368.7  330.5  297.0  260.7
# ..     ...    ...   ...    ...    ...    ...    ...    ...    ...    ...
# 107   67.1   37.6  43.0   46.3  509.3  777.0  564.8  336.7  473.6  455.8
# 108   41.9    8.6   0.0   11.1  238.0  416.6  467.6  321.6  412.9  402.6
# 109  126.8    7.6   3.1  138.2  331.9  346.4  328.9  480.0  523.3  252.1
# 110   72.0   15.8   5.4    2.4  191.1  429.4  301.2  227.7  604.3  287.2
# 111  228.7    5.6  33.0  108.3  275.8  349.1  389.4  414.7  372.8  263.0
#
#        NOV    DEC
# 0    558.2   33.6
# 1    359.0  160.5
# 2    284.4  225.0
# ...

# %%
df_3
# Out:
#      JAN  FEB   MAR  APR   MAY   JUN    JUL    AUG    SEP   OCT  NOV  DEC
# 869  2.6  0.5  24.3  3.3  51.9  64.9  334.9  331.7  235.0  76.6  0.3  1.0
