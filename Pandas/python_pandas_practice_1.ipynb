# %%
import pandas as pd

# %%
ufo = pd.read_csv("http://bit.ly/uforeports")

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns = ufo.columns.str.replace(' ', '_')

# when there are the multiple columns with space in the names then we use bove format

# %%
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.drop(['City'], axis = 1, inplace = True)

# To remove the columns we use above method

# Note: To remove the coulmns we use axis as "1"

# %%
ufo.head()
# Out:
#   Shape_Reported             Time
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00
# 5           DISK  9/15/1934 15:30
# 6         CIRCLE   6/15/1935 0:00

# %%
ufo.drop([ 19], axis = 0, inplace = True)

# To remove the rows we use above method

# Note: To remove the coulmns we use axis as "0"

# %%
ufo.head(20)
# Out:
#                     City Shape_Reported              Time
# 2                Holyoke           OVAL   2/15/1931 14:00
# 3                Abilene           DISK    6/1/1931 13:00
# 4   New York Worlds Fair          LIGHT   4/18/1933 19:00
# 5            Valley City           DISK   9/15/1934 15:30
# 6            Crater Lake         CIRCLE    6/15/1935 0:00
# 7                   Alma           DISK    7/15/1936 0:00
# 8                Eklutna          CIGAR  10/15/1936 17:00
# 9                Hubbard       CYLINDER    6/15/1937 0:00
# 10               Fontana          LIGHT   8/15/1937 21:00
# 11              Waterloo       FIREBALL    6/1/1939 20:00
# 12                Belton         SPHERE   6/30/1939 20:00
# 13                Keokuk           OVAL     7/7/1939 2:00
# 14             Ludington           DISK    6/1/1941 13:00
# 15           Forest Home         CIRCLE    7/2/1941 11:30
# 16           Los Angeles            NaN    2/25/1942 0:00
# ...

# %%
movies = pd.read_csv("http://bit.ly/uforeports")

# %%
movies.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
movies.City.sort_values()

# Sorting the series using the dot notation
# Out:
# 1761     Abbeville
# 4553      Aberdeen
# 16167     Aberdeen
# 14703     Aberdeen
# 389       Aberdeen
#            ...
# 12441          NaN
# 15767          NaN
# 15812          NaN
# 16054          NaN
# 16608          NaN
# Name: City, Length: 18241, dtype: object

# %%
movies["Shape Reported"].sort_values()

# Sorting the series using the Bracket notation
# Out:
# 17522    CHEVRON
# 12806    CHEVRON
# 12810    CHEVRON
# 15927    CHEVRON
# 8257     CHEVRON
#           ...
# 18206        NaN
# 18223        NaN
# 18232        NaN
# 18235        NaN
# 18238        NaN
# Name: Shape Reported, Length: 18241, dtype: object

# %%
movies.sort_values(["City", "Shape Reported", "State"], ascending = False)


# Sorting the Data frame and given the argument as the False so that the values display in the Descending order
# Out:
#                                       City Colors Reported Shape Reported  \
# 6001                   south of the border             NaN           DISK
# 1560                         on plane wing             NaN           DISK
# 12454  observer enroute on MN hwy 61 north           GREEN         SPHERE
# 6786                             not shure             NaN         CIRCLE
# 3459                                  none             NaN         SPHERE
# ...                                    ...             ...            ...
# 1877                                   NaN          YELLOW         CIRCLE
# 2013                                   NaN             NaN            NaN
# 21                                     NaN             NaN            NaN
# 16054                                  NaN           GREEN            NaN
# 5269                                   NaN             NaN            NaN
#
#       State              Time
# 6001     NC   12/1/1988 22:00
# ...
