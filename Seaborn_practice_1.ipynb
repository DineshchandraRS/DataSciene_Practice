# %%
pip install seaborn --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Video-1

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('anagrams')
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
type(sns.load_dataset('anagrams'))
# Out:
# pandas.core.frame.DataFrame

# %%
df1= sns.load_dataset('anagrams')

# %%
df1.head()
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8

# %%
df1.tail()
# Out:
#     subidr    attnr  num1  num2  num3
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
# Video-2 Histogram

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import numpy as np

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.histplot(data = penguins, x = 'flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data = penguins, x = 'flipper_length_mm', binwidth = 1)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data = penguins, x = 'flipper_length_mm', binwidth = 3, kde = True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data = penguins, x = 'flipper_length_mm', binwidth = 3, kde = True, hue = 'species')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# Stacked histograms
sns.histplot(data = penguins, x = 'flipper_length_mm', binwidth = 5, hue = 'species', multiple =  'stack')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# Step Histogram
sns.histplot(data = penguins, x = 'flipper_length_mm', binwidth = 3, hue = 'species', element =  'step')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# Polygonal Histograms
sns.histplot(data = penguins, x = 'flipper_length_mm', binwidth = 5, hue = 'species', element = 'poly')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# Step Histogram
sns.histplot(data = penguins, x = 'flipper_length_mm', binwidth = 5, hue = 'species', element =  'step', stat = 'density', common_norm = False)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data = tips, x = 'size', stat = 'percent', discrete = False)
# Out:
# <AxesSubplot:xlabel='size', ylabel='Percent'>

# %%
sns.histplot(data = tips, x = 'size', stat = 'percent', discrete = True)
# Out:
# <AxesSubplot:xlabel='size', ylabel='Percent'>

# %%
sns.histplot(data = tips, x = 'day', stat = 'percent', shrink = 0.8, hue = 'sex', multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='day', ylabel='Percent'>

# %%
planets = sns.load_dataset('planets')

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.histplot(data = planets, x = 'distance')
# Out:
# <AxesSubplot:xlabel='distance', ylabel='Count'>

# %%
# using Logarithmic scale
sns.histplot(data = planets, x = 'distance', log_scale = True)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='Count'>

# %%
# Not to fill any colors on the plots
sns.histplot(data = planets, x = 'distance', log_scale = True, fill =  False)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='Count'>

# %%
# Step Histogram with not fill colors
sns.histplot(data = planets, x = 'distance', log_scale = True, element = 'step', fill =  False)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='Count'>

# %%
sns.histplot(data = penguins, x = 'bill_depth_mm', y = 'body_mass_g')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %%
sns.histplot(data = penguins, x = 'bill_depth_mm', y = 'body_mass_g', hue = 'species')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %%
sns.histplot(data = planets, x = 'year', y = 'distance', discrete = (True, False), log_scale = (False, True))
# Out:
# <AxesSubplot:xlabel='year', ylabel='distance'>

# %%
# Using Thresh in the plot represents below
sns.histplot(data = planets, x = 'year', y = 'distance', discrete = (True, False), log_scale = (False, True), thresh = None)
# Out:
# <AxesSubplot:xlabel='year', ylabel='distance'>

# %%
# Using pthresh reprsents below:
sns.histplot(data = planets, x = 'year', y = 'distance', discrete = (True, False), log_scale = (False, True), pthresh = 0.5)
# Out:
# <AxesSubplot:xlabel='year', ylabel='distance'>

# %%
# Using pmax reprsents below:
sns.histplot(data = planets, x = 'year', y = 'distance', discrete = (True, False), log_scale = (False, True), pmax = 0.9)
# Out:
# <AxesSubplot:xlabel='year', ylabel='distance'>

# %%
# Adding color bar to the plot and represents below plot
sns.histplot(data = planets, x = 'year', y = 'distance', discrete = (True, False), log_scale = (False, True), cbar = True, cbar_kws = dict(shrink = 0.75))
# Out:
# <AxesSubplot:xlabel='year', ylabel='distance'>

# %%
# Video-3 Scatter Plot

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
import numpy as np

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue ='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# If we use style then different type of markers will display
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style ='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Arguments both hue and style
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue ='time', style = 'time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue ='day', style = 'time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue ='size')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue ='size', palette = 'deep')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tip_rate = tips.eval('tip/total_bill').rename("tip_rate")

# %%
tip_rate
# Out:
# 0      0.059447
# 1      0.160542
# 2      0.166587
# 3      0.139780
# 4      0.146808
#          ...
# 239    0.203927
# 240    0.073584
# 241    0.088222
# 242    0.098204
# 243    0.159744
# Name: tip_rate, Length: 244, dtype: float64

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue =tip_rate)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = 'size', size = 'size')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = 'size', size = 'size', sizes = (20, 200), legend = 'full')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip", hue = 'size', size = 'size', sizes = (20, 200), legend = 'full', hue_norm  = (0, 7))
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
markers =  {'Lunch' : 's', 'Dinner': 'X'}
sns.scatterplot(data = tips, x = "total_bill", y = "tip", style = 'time', markers = markers)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = "total_bill", y = "tip", s = 100, marker = '+', color = ".2")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
index = pd.date_range('1/1/2020', periods = 100, freq = 'm', name = 'date')
data = np.random.randn(100, 4).cumsum(axis = 0)
wide_df = pd.DataFrame(data, index, ['a', 'b', 'c', 'd'])
sns.scatterplot(data= wide_df)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
sns.relplot(data = tips, x = "total_bill", y = "tip", col = 'time', hue ='day', style = 'day', kind = 'scatter')

# %%
# Video-4 KDE Plots

# %%
import matplotlib.pyplot as plt

# %%
import pandas  as pd

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
sns.kdeplot(data = tips, x = 'total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(data = iris)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data = tips, x = 'total_bill', bw_adjust = 5)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data = tips, x = 'total_bill', bw_adjust = 5, cut = 0)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data = tips, x = 'total_bill', hue = 'time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.kdeplot(data = tips, x = 'total_bill', hue = 'size', fill = True, common_norm = False, palette = 'crest', alpha = 0.5, linewidth = 0)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
geyser = sns.load_dataset('geyser')

# %%
sns.kdeplot(data = geyser, x= 'waiting', y = 'duration', hue='kind',levels =5, thresh =.2)
# Out:
# <AxesSubplot:xlabel='waiting', ylabel='duration'>

# %%
sns.kdeplot(data = geyser, x= 'waiting', y = 'duration', fill = True, levels = 100, thresh =0, cmap = 'mako')
# Out:
# <AxesSubplot:xlabel='waiting', ylabel='duration'>

# %%
# Video-5 Rug Plot

# %%
sns.set_theme()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.kdeplot(data = tips, x = 'total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.rugplot(data = tips, x = 'total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.scatterplot(data = tips, x = 'total_bill', y='tip')
sns.rugplot(data = tips, x = 'total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = 'total_bill', y='tip', hue = 'time')
sns.rugplot(data = tips, x = 'total_bill', y='tip', hue ='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = 'total_bill', y='tip', hue = 'time')
sns.rugplot(data = tips, x = 'total_bill', y='tip', hue ='time', height = 0.2)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = 'total_bill', y='tip', hue = 'time')
sns.rugplot(data = tips, x = 'total_bill', y='tip', hue ='time', height = -0.2, clip_on = False)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Video-6 CountPlot

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.countplot(data = titanic, x = 'class')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(data = titanic, x = 'class', hue = 'who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(data = titanic, y = 'class', hue = 'who')
# Out:
# <AxesSubplot:xlabel='count', ylabel='class'>

# %%
sns.countplot(data = titanic, x = 'who', palette='Set3')
# Out:
# <AxesSubplot:xlabel='who', ylabel='count'>

# %%
sns.countplot(data = titanic, x = 'who', palette='Set3', facecolor = (0, 0, 0, 0), linewidth = 5, edgecolor = sns.color_palette('dark', 3))
# Out:
# <AxesSubplot:xlabel='who', ylabel='count'>

# %%
sns.catplot(data = titanic, x = 'class', hue = 'who', col = 'survived', kind = 'count', aspect = 0.7, height = 4)

# %%
# Video-7 Regplot

# %%
sns.regplot(data = tips, x='total_bill', y = 'tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
np.random.seed(8)
mean, cov = [4, 6], [(1.5, .7), (0.7, 1)]
x, y = np.random.multivariate_normal(mean, cov, 80).T
sns.regplot(x= x, y = y, color = 'g')
# Out:
# <AxesSubplot:>

# %%
x = pd.Series(x, name = 'x_var')
x = pd.Series(y, name = 'y_var')
sns.regplot(x = x, y = y, marker = '+')
# Out:
# <AxesSubplot:xlabel='y_var'>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
sns.set_theme(color_codes = True)

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.regplot(data = tips, x='total_bill', y = 'tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
np.random.seed(8)
mean, cov = [4, 6], [(1.5, .7), (0.7, 1)]
x, y = np.random.multivariate_normal(mean, cov, 80).T
sns.regplot(x= x, y = y, color = 'g')
# Out:
# <AxesSubplot:>

# %%
x = pd.Series(x, name = 'x_var')
x = pd.Series(y, name = 'y_var')
sns.regplot(x = x, y = y, marker = '+')
# Out:
# <AxesSubplot:xlabel='y_var'>

# %%
sns.regplot(data = tips, y='total_bill', x = 'size', x_jitter = 0.1)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.regplot(data = tips, y='total_bill', x = 'size', x_estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Video- 8

# %%
def sinplot(flip = 1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * 0.5) * (7 - i) * flip)

# %%
sinplot()

# %%
sns.set_theme()
sinplot()

# %%
sns.set_style("whitegrid")
sinplot()

# %%
sns.set_style("white")
sinplot()

# %%
sns.set_style("dark")
sinplot()

# %%
sns.set_style("ticks")
sinplot()

# %%
# Removing  axes spines
sinplot()
sns.despine()

# %%
sinplot()
sns.despine(offset = 10, trim = True)

# %%
sinplot()
sns.despine(left = True)

# %%
f= plt.figure(figsize = (6,6))
gs = f.add_gridspec(2,2)

with sns.axes_style('darkgrid'):
    ax = f.add_subplot((gs[0,0]))
    sinplot()
    
with sns.axes_style('dark'):
    ax = f.add_subplot((gs[0,1]))
    sinplot()

with sns.axes_style('ticks'):
    ax = f.add_subplot((gs[1,0]))
    sinplot()

with sns.axes_style('white'):
    ax = f.add_subplot((gs[1,1]))
    sinplot()

f.tight_layout()

# %%
# Video-9

# %%
sns.set_theme(color_codes = True)

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lmplot(data = tips, x='total_bill', y = 'tip', hue = 'smoker')

# %%
sns.lmplot(data = tips, x='total_bill', y = 'tip', hue = 'smoker', markers = ['o', 'x'])

# %%
sns.lmplot(data = tips, x='total_bill', y = 'tip', hue = 'smoker', palette = 'Set1', markers = ['o', 'x'])

# %%
sns.lmplot(data = tips, x='total_bill', y = 'tip', col = 'smoker')

# %%
sns.lmplot(data = tips,x='total_bill', y = 'tip', hue = 'day', col = 'day', col_wrap = 2, height = 4)

# %%
sns.lmplot(data = tips,x='total_bill', y = 'tip', row = 'sex', col = 'time', height = 4)
